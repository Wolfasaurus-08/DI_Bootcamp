# %% [markdown]
# <a href="https://colab.research.google.com/github/Wolfasaurus-08/DI_Bootcamp/blob/main/wk3day2_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Exercise 1: Identifying Data Types
# Below are various data sources. Identify whether each one is an example of structured or unstructured data.
#
# A company’s financial reports stored in an Excel file. **structured**
#
# Photographs uploaded to a social media platform. **unstructured**
#
# A collection of news articles on a website.**unstructured**
#
# Inventory data in a relational database. **structured**
#
# Recorded interviews from a market research study. **unstructured**

# %% [markdown]
# #Exercise 2: Transformation Exercise
# For each of the following unstructured data sources, propose a method to convert it into structured data. Explain your reasoning.
#
# A series of blog posts about travel experiences. **use text analysis to get details like destinations, dates, anctivities, and ages of travelers.**
#
# Audio recordings of customer service calls. **convert it to text and analyze the text for customer details, issues and solutions.**
#
# Handwritten notes from a brainstorming session. **Digitize them and seperate them by themes or subjects. Also number the note cards to make it searchable**
#
# A video tutorial on cooking. **analyze the video for ingredients, steps, and times implementing the steps, total cooking time and number of servings in total**

# %%
# 🌟 Exercise 3 : Import a file from Kaggle (tried to import from kaggle, but there
# are so many train.csv files, and we only got the download link from the excersise.)
# Import the train dataset. Use the train.csv file.
# Print the first few rows of the DataFrame.
import pandas as pd
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 🌟 Exercise 4: Importing a CSV File
# Use the Iris Dataset CSV.

# Download the Iris dataset CSV file and place it in the same directory as your Jupyter Notebook.
# Import the CSV file using Pandas.
# Display the first five rows of the dataset.

import pandas as pd
df = pd.read_csv('Iris_dataset.csv')
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import pandas as pd
from faker import Faker

fake = Faker()

people = {
    'Name': [fake.name() for _ in range(10)],
    'Age': [fake.random_int(min=18, max=80) for _ in range(10)],
    'City': [fake.city() for _ in range(10)]
}

df = pd.DataFrame(people)

print(df)
# Out:
#                   Name  Age              City
# 0  Rebecca Mcbride DVM   28      South Monica
# 1       Jason Anderson   67        New Joseph
# 2      Michelle Vaughn   72    East Shawnfurt
# 3      Christina Green   56   Port Kevinville
# 4        Michael Allen   42  North Angelastad
# 5           Mary Brady   33      Mcintyreland
# 6           Ian Cooper   35         Anneville
# 7       Jesse Mccarthy   35     East Jillfurt
# 8           Cory Frank   22        South John
# 9      Christine Price   58        Aaronmouth

# %%
df.to_excel('people.xlsx', index=False)

# %%
# Export the DataFrame to a JSON file
df.to_json('people.json', orient='records', lines=True)

# %%
# 🌟 Exercise 6: Reading JSON Data
# Use a sample JSON dataset

# Import the JSON data from the provided URL. (no URL, just the raw data file)
# Use Pandas to read the JSON data.
# Display the first five entries of the data.

# %%
import requests, zipfile, io

# URL of the zip file containing JSON data
url = 'https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/posts.zip'

# Download and extract the zip file
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall('posts')

import pandas as pd

# Replace 'path_to_json_file.json' with the actual path to your JSON file
json_file_path = 'posts/posts.json'

# Read the JSON data into a DataFrame
df = pd.read_json(json_file_path)

# Display the first five entries
print(df.head())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
